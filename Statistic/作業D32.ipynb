# %% [markdown]
# <a href="https://colab.research.google.com/github/GaryPython/Data-science-marathon/blob/main/Statistic/%E4%BD%9C%E6%A5%ADD32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 作業:
# 在課堂中，檢定 𝐻_0:𝜇≤0， 𝐻_1:𝜇>0 ，假設在 𝐻_0 為真下，分配為 N(0,1)， 𝐻_1 為真下，分配為 N(2,1)。
# 假設 𝑋 ̅>1，拒絕 𝐻_0。
# 如果拒絕域改變時，𝛼 和 𝛽 會怎樣變化，
# ![](sample mean 1.png)
# 可以拿起一張紙，試著畫畫看，就能找到答案。

# %% [markdown]
# ![sample mean 1.png](data:image/png;base64,...)

# %% [markdown]
# ![擷取.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### Q1: 假設 𝑋 ̅>2，拒絕 𝐻_0，𝛼 會變大/變小? 𝛽 會變大/變小?

# %% [markdown]
# ![sample mean 2.png](data:image/png;base64,...)

# %%
'''
你的答案
𝛼變小，𝛽變大
'''
# Out:
# '\n你的答案\n'

# %% [markdown]
# ### Q2: 假設 𝑋 ̅>0.2，拒絕 𝐻_0，𝛼 會變大/變小? 𝛽 會變大/變小?

# %% [markdown]
# ![sample mean 0_2.png](data:image/png;base64,...)

# %%
'''
你的答案
'''
𝛼變大，𝛽變小
# Out:
# '\n你的答案\n'

# %% [markdown]
# ### Q3: 𝛼 和 𝛽  有關聯性?

# %%
'''
你的答案
彼此是權衡的概念，
alpha會變大，beta就會變小
alpha會變小，beta就會變大
'''
# Out:
# '\n你的答案\n'
